# %% [markdown]
# ##Resultados do treinamento

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Os treinamentos foram realizados 10 vezes cada, sendo que cada vez foi realizada a validação cruzada 5-folds

# %%
 teste = pd.read_csv('./trainResults_1.csv');

# %%
mediaTeste1 = teste.groupby(['Key_Dataset','Key_Scheme','Key_Scheme_options']).aggregate(np.mean)

# %%
results = mediaTeste1[['Percent_correct']]

# %% [markdown]
# Apresentamos os valores médios de acurácia:

# %%
results
# Out:
#                                                                                                                                                                  Percent_correct
# Key_Dataset  Key_Scheme                        Key_Scheme_options
# trainSort    weka.classifiers.bayes.NaiveBayes ''                                                                                                                      91.593407
#              weka.classifiers.lazy.IB1         ''                                                                                                                      99.714286
#              weka.classifiers.lazy.IBk         '-K 2 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        98.989011
#                                                '-K 3 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        99.417582
#                                                '-K 4 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        98.835165
#              weka.classifiers.trees.J48        '-C 0.25 -M 2'                                                                                                          86.703297
# train_Limpos weka.classifiers.bayes.NaiveBayes ''                                                                                                                      90.769231
#              weka.classifiers.lazy.IB1         ''                                                                                                                      94.087912
#              weka.classifiers.lazy.IBk         '-K 2 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        91.648352
#                                                '-K 3 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        92.351648
#                                                '-K 4 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        92.758242
#              weka.classifiers.trees.J48        '-C 0.25 -M 2'                                                                                                          78.494505
# train_top10  weka.classifiers.bayes.NaiveBayes ''                                                                                                                      91.153846
#              weka.classifiers.lazy.IB1         ''                                                                                                                      99.714286
#              weka.classifiers.lazy.IBk         '-K 2 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        99.428571
#                                                '-K 3 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        98.714286
#                                                '-K 4 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        98.142857
#              weka.classifiers.trees.J48        '-C 0.25 -M 2'                                                                                                          87.175824
# train_top12  weka.classifiers.bayes.NaiveBayes ''                                                                                                                      92.747253
#              weka.classifiers.lazy.IB1         ''                                                                                                                      98.681319
#              weka.classifiers.lazy.IBk         '-K 2 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        99.263736
#                                                '-K 3 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        99.263736
#                                                '-K 4 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        98.967033
#              weka.classifiers.trees.J48        '-C 0.25 -M 2'                                                                                                          86.483516
# train_top2   weka.classifiers.bayes.NaiveBayes ''                                                                                                                      93.813187
#              weka.classifiers.lazy.IB1         ''                                                                                                                      97.109890
#              weka.classifiers.lazy.IBk         '-K 2 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        96.813187
#                                                '-K 3 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        97.109890
#                                                '-K 4 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        96.824176
#              weka.classifiers.trees.J48        '-C 0.25 -M 2'                                                                                                          77.571429
# ...                                                                                                                                                                          ...
# train_top25  weka.classifiers.bayes.NaiveBayes ''                                                                                                                      93.054945
#              weka.classifiers.lazy.IB1         ''                                                                                                                      99.131868
#              weka.classifiers.lazy.IBk         '-K 2 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        98.549451
#                                                '-K 3 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        98.989011
#                                                '-K 4 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        99.857143
#              weka.classifiers.trees.J48        '-C 0.25 -M 2'                                                                                                          84.087912
# train_top30  weka.classifiers.bayes.NaiveBayes ''                                                                                                                      92.340659
#              weka.classifiers.lazy.IB1         ''                                                                                                                      96.527473
#              weka.classifiers.lazy.IBk         '-K 2 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        97.263736
#                                                '-K 3 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        98.549451
#                                                '-K 4 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        99.131868
#              weka.classifiers.trees.J48        '-C 0.25 -M 2'                                                                                                          83.032967
# train_top4   weka.classifiers.bayes.NaiveBayes ''                                                                                                                      94.791209
#              weka.classifiers.lazy.IB1         ''                                                                                                                      97.219780
#              weka.classifiers.lazy.IBk         '-K 2 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        98.098901
#                                                '-K 3 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        97.648352
#                                                '-K 4 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        99.857143
#              weka.classifiers.trees.J48        '-C 0.25 -M 2'                                                                                                          77.626374
# train_top6   weka.classifiers.bayes.NaiveBayes ''                                                                                                                      93.725275
#              weka.classifiers.lazy.IB1         ''                                                                                                                      97.252747
#              weka.classifiers.lazy.IBk         '-K 2 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        96.956044
#                                                '-K 3 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        97.252747
#                                                '-K 4 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        96.516484
#              weka.classifiers.trees.J48        '-C 0.25 -M 2'                                                                                                          86.989011
# train_top8   weka.classifiers.bayes.NaiveBayes ''                                                                                                                      92.747253
#              weka.classifiers.lazy.IB1         ''                                                                                                                      97.967033
#              weka.classifiers.lazy.IBk         '-K 2 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        98.846154
#                                                '-K 3 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        98.120879
#                                                '-K 4 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        98.263736
#              weka.classifiers.trees.J48        '-C 0.25 -M 2'                                                                                                          86.637363
#
# [66 rows x 1 columns]

# %% [markdown]
# Os 5 melhores

# %%
results.sort('Percent_correct', ascending=False)[:5]
# Out:
#                                                                                                                                                         Percent_correct
# Key_Dataset Key_Scheme                Key_Scheme_options
# train_top4  weka.classifiers.lazy.IBk '-K 4 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        99.857143
# train_top25 weka.classifiers.lazy.IBk '-K 4 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        99.857143
# train_top10 weka.classifiers.lazy.IB1 ''                                                                                                                      99.714286
# trainSort   weka.classifiers.lazy.IB1 ''                                                                                                                      99.714286
# train_top10 weka.classifiers.lazy.IBk '-K 2 -W 0 -A \"weka.core.neighboursearch.LinearNNSearch -A \\\"weka.core.EuclideanDistance -R first-last\\\"\"'        99.428571

# %% [markdown]
# O melhor fica sendo 1bk com k igual 4 para os atributos correstpondentes ao arquivo train_top4 ou train_top25
