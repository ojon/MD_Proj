# %% [markdown]
# ##Predições para o conjunto de testes

# %% [markdown]
# Inicialmente lemos o arquivo do conjunto de testes e preparamos os dados:

# %%
import pandas as pd
import numpy as np

# %%
 raw_dadosTeste = pd.read_csv('./pp5i_test.gr.csv');

# %%
raw_dadosTeste[:3]
# Out:
#            SNO  101  102  103  104  105  106  107  108  109 ...   114  115  \
# 0    A28102_at   58   52   13   46   48   31   16   23   47 ...    11   19
# 1  AB000114_at   36   34   32   30   22   57   17   19   29 ...    17   57
# 2  AB000115_at   10  255    0   14   17   -6   15   17   33 ...    18   -2
#
#    116  117  118  119  120  121  122  123
# 0   18   70   50   29   47   44   56  119
# 1   25   50   36   26   28   34   45   53
# 2   -7  148  145   13  361   16    7   34
#
# [3 rows x 24 columns]

# %% [markdown]
# Organizamos de forma que os genes fiquem nas colunas

# %%
dadosTeste = raw_dadosTeste.transpose()
newColumns = dadosTeste[:1]
dadosTeste.columns = newColumns.values.flat;
dadosTeste = dadosTeste.drop('SNO')

# %%
dadosTeste[:3]
# Out:
#     A28102_at AB000114_at AB000115_at AB000220_at AB000409_at AB000449_at  \
# 101        58          36          10          64          17           8
# 102        52          34         255          19         220          28
# 103        13          32           0         133         186          -6
#
#     AB000450_at AB000460_at AB000462_at AB000464_at     ...     U58516_at  \
# 101         -36         222         119         254     ...           216
# 102           3         209          93         143     ...           236
# 103         -58         174          66         204     ...           138
#
#     U73738_at X06956_at X16699_at X83863_at Z17240_at L49218_f_at M71243_f_at  \
# 101         0        10        -2       288        74           5          61
# 102         0        20         1       161        33           6          22
# 103        -5        33       -21       400        36         -24          55
#
#     Z78285_f_at  NaN
# 101           0  NaN
# 102          -1  NaN
# 103           2  NaN
#
# [3 rows x 7071 columns]

# %%
dadosTesteThreshold = dadosTeste.clip(upper=16000, lower=20)
dadosTesteLimpos =  dadosTesteThreshold.loc[:,(dadosTesteThreshold.max(axis=0) - dadosTesteThreshold.min(axis=0)) > 2]

# %% [markdown]
# ###Seleção de atributos para os dados de teste

# %% [markdown]
# ####Conjunto com os melhores 4 genes por classes

# %% [markdown]
# Lemos o arquivo que anteriormente com um subconjunto de atributos(genes no nosso caso) no processo de treinamento.

# %%
topGenesFilename = ('./train_top4.csv')
top4Genes = pd.read_csv(topGenesFilename)

# %%
top4Genes[:3]
# Out:
#    M20137_at  D14662_at  D13631_s_at  X00371_rna1_at  D00763_at  M16447_at  \
# 0        113        135           20              44        127         40
# 1        109        292           20              40        489         65
# 2        133        203           20              40        131         48
#
#    D85815_at  D80004_at  M31303_rna1_at  D25304_at    ...      U07550_at  \
# 0        274        387             830         84    ...             70
# 1        147        138             404        241    ...            457
# 2        263        183             467        136    ...            122
#
#    X76105_at  HG3514-HT3708_at  U16954_at  J03191_at  M57464_s_at  \
# 0         49               372       1102        237           96
# 1        101               505         54       1029          292
# 2         93               271        387        155          130
#
#    V01515_cds1_at  U79262_at  U79294_at  Class
# 0              28        196        104    MED
# 1              20         75        101    RHB
# 2              52        111        160    MED
#
# [3 rows x 21 columns]

# %% [markdown]
# Isto é feito somente para obtermos a lista de genes. Esta lista é usada para filtar as colunas dos dados de teste. Acionamos também uma coluna 'Class' com valores ?. Este é o preocedimento para fazer predições com o weka futuramente.

# %%
selGenes = top4Genes.columns[:-1]
selectedData = dadosTesteLimpos[selGenes]
selectedData['Class'] = '?'

# %%
selectedData
# Out:
#     M20137_at D14662_at D13631_s_at X00371_rna1_at D00763_at M16447_at  \
# 101       160        86          44             63        71        61
# 102       120       626         165             21       348        97
# 103        92       106          20             20        37        24
# 104        92       158          20             50       203        32
# 105       119       409          66             29       295        68
# 106       124       129          20             23        82        54
# 107       110        63          37             27        95        69
# 108        95       144          22             41       237       161
# 109       116       653          72             35       348       117
# 110       110       237         278             32       224       247
# 111       115       260         326             38       233       245
# 112       123       112          20             57       141        43
# 113        94       253          20             28       450        37
# 114       126        51          20             42       117        36
# 115        81        49          20             51        20        20
# 116       160       123          20             23       123        20
# 117       135       203         231             49       247        79
# 118        84       242          43             24       406        50
# 119       127       173          20             38       450        84
# 120        95       259          20             34       300        75
# 121        89       285          59             35       227        42
# 122       147       134          20             44       152        69
# 123       127       320          56             53       295        20
#
#     D85815_at D80004_at M31303_rna1_at D25304_at    ...    U07550_at  \
# 101       342       148            222       181    ...           53
# 102       182       147            312       397    ...          489
# 103       198        77            760        20    ...          105
# 104       263       168            718       127    ...          152
# 105       201       108            301       211    ...          449
# 106       279       172            510        56    ...           40
# 107       291       169            836       118    ...          136
# 108       176       164            749       118    ...          206
# 109       167       106            273       295    ...          409
# 110       182        60            306       580    ...          289
# 111        91        37            261       736    ...          296
# 112       255       263            511        81    ...          111
# 113       135       331            676       195    ...          474
# 114       290       498           1035        61    ...           98
# 115       264       500            525        20    ...          108
# 116       370       129            729        78    ...          122
# 117       249        36            228       598    ...          206
# 118       155       291            549       228    ...          454
# 119       172       146            736       179    ...          243
# 120       152       163            563       226    ...         2226
# 121       159       109            278       320    ...          299
# 122       305       345            540       175    ...          165
# 123       232        83            140       324    ...          191
#
#     X76105_at HG3514-HT3708_at U16954_at J03191_at M57464_s_at V01515_cds1_at  \
# 101        20              182       566        20          89             69
# 102       124              381       296       228          59             24
# 103        20              150       989       158          20             56
# 104        49              250      1151       151         168             48
# 105       214              421        35       253         108             29
# 106        20              157       512       176          59             39
# 107       155              265       707       236         230             44
# 108       217              316      1080        48          28             32
# 109       172              320       128       333          67             26
# 110        78              270       369       240          65             24
# 111       115              339       334       276          45             27
# 112        72              287      1190        20          20             22
# 113        97              494       959       276         192             21
# 114        25              240       912        20          43             27
# 115        20              170      1182       130          40             60
# 116        59              127       529       227         219             34
# 117       134              259       429       198          78             33
# 118       131              283       992       218         193             30
# 119       155              361      1348       270         219             20
# 120        20              386       569       863         390             27
# 121       103              346       167       441         203             26
# 122        20              232       651       126         180             63
# 123       155              436        99       346         205             32
#
#     U79262_at U79294_at Class
# 101       144       118     ?
# 102       133       537     ?
# 103        97        20     ?
# 104       149        73     ?
# 105        90       175     ?
# 106       196       178     ?
# 107       200       235     ?
# 108       206       134     ?
# 109        78       592     ?
# 110       111       779     ?
# 111        84       732     ?
# 112        74        55     ?
# 113       192       160     ?
# 114       227       125     ?
# 115       115       400     ?
# 116       211       189     ?
# 117        66       238     ?
# 118       136       112     ?
# 119       233       113     ?
# 120       115        78     ?
# 121       126       157     ?
# 122       151       121     ?
# 123        80       110     ?
#
# [23 rows x 21 columns]

# %% [markdown]
# O resultado é salvo em um arquivo .csv

# %%
selectedData.to_csv('test_top4.csv', index=False)

# %% [markdown]
# Este arquivo é lido com o weka lá é convertido no formato arff, o mesmo é feito com os dados de treinamento. O treinamento é realizado no weka e os dados são reavaliados no conjunto de teste, com a opção de fornecer a lista de predições. O resultado é salvo em um novo arquivo no formato .csv

# %% [markdown]
# Vamos observar as predições para as combinações de nossos melhores esquemas de seleção de atributos combinados com classificadores:

# %% [markdown]
# #### Predições IBk k=4 atributos selecionados com base nos top4 genes

# %%
results = pd.read_csv('./testResults_top4_ibk_k4.csv')
ibk4_top4 = results[['inst#','predicted']][:23]
ibk4_top4['Scheme'] = 'ibk4_top4'
ibk4_top4
# Out:
#     inst# predicted     Scheme
# 0       1     3:MGL  ibk4_top4
# 1       2     4:EPD  ibk4_top4
# 2       3     1:MED  ibk4_top4
# 3       4     1:MED  ibk4_top4
# 4       5     4:EPD  ibk4_top4
# 5       6     1:MED  ibk4_top4
# 6       7     1:MED  ibk4_top4
# 7       8     1:MED  ibk4_top4
# 8       9     4:EPD  ibk4_top4
# 9      10     5:JPA  ibk4_top4
# 10     11     5:JPA  ibk4_top4
# 11     12     1:MED  ibk4_top4
# 12     13     1:MED  ibk4_top4
# 13     14     1:MED  ibk4_top4
# 14     15     1:MED  ibk4_top4
# 15     16     1:MED  ibk4_top4
# 16     17     5:JPA  ibk4_top4
# 17     18     1:MED  ibk4_top4
# 18     19     1:MED  ibk4_top4
# 19     20     2:RHB  ibk4_top4
# 20     21     2:RHB  ibk4_top4
# 21     22     1:MED  ibk4_top4
# 22     23     4:EPD  ibk4_top4

# %% [markdown]
# #### Vizinho mais próximo com os dados brutos

# %% [markdown]
# #### Predições MultiLayer Perceptron com os top genes
